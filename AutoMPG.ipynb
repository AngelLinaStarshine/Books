# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelLinaStarshine/Books/blob/master/AutoMPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler

column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'car_name']
auto_mpg_df = pd.read_csv('auto-mpg.data', delim_whitespace=True, names=column_names, na_values='?')

auto_mpg_df.drop(columns=['car_name', 'origin'], inplace=True)

auto_mpg_df['horsepower'] = auto_mpg_df.groupby('cylinders')['horsepower'].transform(lambda x: x.fillna(x.mean()))

auto_mpg_df['model_year'] = auto_mpg_df['model_year'] + 1900

auto_mpg_df.head()

X = auto_mpg_df.drop('mpg', axis=1)
y = auto_mpg_df['mpg']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.5, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)


model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(X_train_scaled, y_train, epochs=50, validation_data=(X_val_scaled, y_val))

new_vehicles = pd.DataFrame({
    'cylinders': [6, 12, 8, 8, 4, 6, 3, 3, 4, 4],
    'displacement': [2170, 6498, 3902, 6162, 122, 3232, 598, 900, 1189, 201],
    'horsepower': [502, 730, 986, 670, 181, 155, 89, 50, 60, 40],
    'weight': [3164, 3472, 3020, 3721, 2496, 3232, 1550, 642, 2355, 2265],
    'acceleration': [4.2, 3.2, 2.5, 2.6, 8.3, 11.5, 10.1, 5.8, 28.1, 32],
    'model_year': [2025, 2025, 2025, 2025, 2025, 1969, 2025, 2025, 1964, 1908]
})

new_vehicles_scaled = scaler.transform(new_vehicles)

predicted_mpg = model.predict(new_vehicles_scaled)

predicted_mpg

val_loss = model.evaluate(X_val_scaled, y_val)

print(f'Validation Loss: {val_loss}')
# Out:
# --2024-09-25 01:12:16--  https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘auto-mpg.data’
#
# auto-mpg.data           [ <=>                ]  29.58K  --.-KB/s    in 0.06s
#
# 2024-09-25 01:12:17 (462 KB/s) - ‘auto-mpg.data’ saved [30286]
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 607.8004 - val_loss: 585.4216
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 625.3311 - val_loss: 570.1957
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 597.6831 - val_loss: 554.5759
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 558.3597 - val_loss: 536.8030
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 528.1950 - val_loss: 515.8027
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 525.4303 - val_loss: 491.0179
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 490.9209 - val_loss: 462.3221
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 479.2924 - val_loss: 428.2797
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 420.1697 - val_loss: 389.5955
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 423.3751 - val_loss: 346.2069
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 356.0862 - val_loss: 299.6642
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 301.0179 - val_loss: 250.3206
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 237.4857 - val_loss: 199.8272
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 209.6958 - val_loss: 151.6160
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 158.6225 - val_loss: 111.5828
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 114.8198 - val_loss: 80.9054
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 82.8125 - val_loss: 61.7290
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 57.5291 - val_loss: 53.5878
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 48.8895 - val_loss: 52.0302
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 45.4707 - val_loss: 51.8495
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 42.7498 - val_loss: 50.7860
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 42.6184 - val_loss: 49.2246
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 39.8627 - val_loss: 47.0827
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.6382 - val_loss: 44.3407
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 36.9317 - val_loss: 42.2272
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 34.1439 - val_loss: 40.6186
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.4398 - val_loss: 39.0803
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.3887 - val_loss: 37.3186
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.4497 - val_loss: 35.8057
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.8960 - val_loss: 34.4370
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 29.0170 - val_loss: 33.1933
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.0096 - val_loss: 31.7935
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.4304 - val_loss: 30.5110
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.3704 - val_loss: 29.2843
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 20.2122 - val_loss: 28.1281
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.7057 - val_loss: 26.9771
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 18.3591 - val_loss: 25.8996
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 21.3849 - val_loss: 24.7614
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.0103 - val_loss: 23.8489
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.6379 - val_loss: 22.8097
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.8514 - val_loss: 22.0973
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.3814 - val_loss: 21.3734
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.8291 - val_loss: 20.7871
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.9955 - val_loss: 20.0970
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.0674 - val_loss: 19.4776
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.1106 - val_loss: 18.7614
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.3231 - val_loss: 17.9870
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.1763 - val_loss: 17.2415
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 16.1258 - val_loss: 16.9120
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 12.8269 - val_loss: 16.5529
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.1006
# Validation Loss: 16.552871704101562
