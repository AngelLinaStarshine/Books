# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelLinaStarshine/Books/blob/master/AutoMPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from sklearn.preprocessing import StandardScaler

column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'car_name']
auto_mpg_df = pd.read_csv('auto-mpg.data', delim_whitespace=True, names=column_names, na_values='?')

auto_mpg_df.drop(columns=['car_name', 'origin'], inplace=True)

auto_mpg_df['horsepower'] = auto_mpg_df.groupby('cylinders')['horsepower'].transform(lambda x: x.fillna(x.mean()))

auto_mpg_df['model_year'] = auto_mpg_df['model_year'] + 1900

auto_mpg_df.head()

X = auto_mpg_df.drop('mpg', axis=1)
y = auto_mpg_df['mpg']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.5, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)


model = Sequential([
    Input(shape=(X_train_scaled.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(X_train_scaled, y_train, epochs=50, validation_data=(X_val_scaled, y_val))

new_vehicles = pd.DataFrame({
    'cylinders': [6, 12, 8, 8, 4, 6, 3, 3, 4, 4],
    'displacement': [2170, 6498, 3902, 6162, 122, 3232, 598, 900, 1189, 201],
    'horsepower': [502, 730, 986, 670, 181, 155, 89, 50, 60, 40],
    'weight': [3164, 3472, 3020, 3721, 2496, 3232, 1550, 642, 2355, 2265],
    'acceleration': [4.2, 3.2, 2.5, 2.6, 8.3, 11.5, 10.1, 5.8, 28.1, 32],
    'model_year': [2025, 2025, 2025, 2025, 2025, 1969, 2025, 2025, 1964, 1908]
})

new_vehicles_scaled = scaler.transform(new_vehicles)

predicted_mpg = model.predict(new_vehicles_scaled)

predicted_mpg

val_loss = model.evaluate(X_val_scaled, y_val)

print(f'Validation Loss: {val_loss}')
# Out:
# --2024-09-25 01:32:55--  https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘auto-mpg.data.2’
#
# auto-mpg.data.2         [ <=>                ]  29.58K  --.-KB/s    in 0.06s
#
# 2024-09-25 01:32:55 (481 KB/s) - ‘auto-mpg.data.2’ saved [30286]
#
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 632.3400 - val_loss: 602.2297
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 604.7035 - val_loss: 589.8712
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 587.7418 - val_loss: 578.0794
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 601.4081 - val_loss: 565.1050
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 547.6090 - val_loss: 550.4500
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 551.4505 - val_loss: 532.8495
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 545.1050 - val_loss: 512.2872
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 491.4857 - val_loss: 488.6372
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 516.0194 - val_loss: 461.0925
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 478.3889 - val_loss: 430.1927
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 498.0372 - val_loss: 395.1453
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 404.2052 - val_loss: 356.8424
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 356.4949 - val_loss: 314.0381
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 324.8880 - val_loss: 268.3661
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 258.9265 - val_loss: 220.7876
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 237.1561 - val_loss: 173.7308
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 177.0008 - val_loss: 130.9046
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 126.4255 - val_loss: 95.2131
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 104.8383 - val_loss: 68.7368
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 65.5923 - val_loss: 52.7731
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 53.5301 - val_loss: 45.6673
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 41.7062 - val_loss: 44.1030
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 36.0889 - val_loss: 44.2286
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 33.8655 - val_loss: 43.7548
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.0272 - val_loss: 42.3309
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.0075 - val_loss: 40.0122
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 29.5079 - val_loss: 37.8952
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.6222 - val_loss: 35.9538
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.2665 - val_loss: 34.4048
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.4630 - val_loss: 32.9160
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.5864 - val_loss: 31.3840
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.8264 - val_loss: 30.1805
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 27.9362 - val_loss: 29.2901
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.6212 - val_loss: 28.4862
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.6059 - val_loss: 27.5116
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 21.0284 - val_loss: 26.7734
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 19.9797 - val_loss: 25.7640
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.8086 - val_loss: 24.9047
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.3707 - val_loss: 24.2970
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.5243 - val_loss: 23.5680
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.9258 - val_loss: 22.6273
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.6584 - val_loss: 21.7202
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 18.4132 - val_loss: 20.9946
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.4846 - val_loss: 20.5256
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 17.8443 - val_loss: 20.1775
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 17.8872 - val_loss: 19.8397
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.7623 - val_loss: 19.2575
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.1972 - val_loss: 18.6669
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 14.8797 - val_loss: 18.2771
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 17.1975 - val_loss: 17.6168
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.9997
# Validation Loss: 17.616844177246094
